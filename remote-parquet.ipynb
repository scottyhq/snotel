# %%
import fsspec
import geopandas as gpd

# %%
with fsspec.open('https://github.com/scottyhq/snotel/raw/main/snotel-sites.geoparquet') as f:
    gf = gpd.read_parquet(f)

# %%
gf.head()
# Out:
#                         name  elevation_m   latitude   longitude  \
# code
# 301_CA_SNTL         Adin Mtn  1886.712036  41.235828 -120.791924
# 907_UT_SNTL      Agua Canyon  2712.719971  37.522171 -112.271179
# 916_MT_SNTL       Albro Lake  2529.840088  45.597229 -111.959023
# 1267_AK_SNTL  Alexander Lake    48.768002  61.749668 -150.889664
# 908_WA_SNTL   Alpine Meadows  1066.800049  47.779572 -121.698471
#
#                          county       state  beginDate    endDate  isActive  \
# code
# 301_CA_SNTL               Modoc  California 1983-10-01 2100-01-01      True
# 907_UT_SNTL                Kane        Utah 1994-10-01 2100-01-01      True
# 916_MT_SNTL             Madison     Montana 1996-09-01 2100-01-01      True
# 1267_AK_SNTL  Matanuska-Susitna      Alaska 2014-08-28 2100-01-01      True
# 908_WA_SNTL                King  Washington 1994-09-01 2100-01-01      True
#
#                                  geometry
# code
# 301_CA_SNTL   POINT (-120.79192 41.23583)
# ...
